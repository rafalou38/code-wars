# %% [markdown]
# <a href="https://colab.research.google.com/github/rafalou38/code-wars/blob/main/Roman_Numerals_Helper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf sample_data/

# %% [markdown]
# # Roman Numerals Helper
#
# - *02/01/2021*
# - **5 kyu**
# - **url:** https://www.codewars.com/kata/51b66044bce5799a7f000003
#
# ------
# ##Task
#
#
# Create a RomanNumerals class that can convert a roman numeral to and from an integer value. It should follow the API demonstrated in the examples below. Multiple roman numeral values will be tested for each helper method.
#
# Modern Roman numerals are written by expressing each digit separately starting with the left most digit and skipping any digit with a value of zero. In Roman numerals 1990 is rendered: 1000=M, 900=CM, 90=XC; resulting in MCMXC. 2008 is written as 2000=MM, 8=VIII; or MMVIII. 1666 uses each Roman symbol in descending order: MDCLXVI.
#
# ----------
# ##Examples
#
# ```python
# RomanNumerals.to_roman(1000) # should return 'M'
# RomanNumerals.from_roman('M') # should return 1000
# ```
#
# -----
# #Help
# | Symbol | Value |
# | ------ |:-----:|
# | I      |  1    |
# | V      |  5    |
# | X      |  10   |
# | L      |  50   |
# | C      |  100  |
# | D      |  500  |
# | M      |  1000 |

# %%
class RomanNumerals:
    numbers = {
        1    : "I",
        5    : "V",
        10   : "X",
        50   : "L",
        100  : "C",
        500  : "D",
        1000 : "M"
    }
    @classmethod
    def to_roman(cls, number: str):
        s = "I" * number
        print(s)
        
        s = s.replace("IIIII", "V")
        print(s)
        s = s.replace("IIII", "IV")
        print(s)
        
        s = s.replace("VV", "X")
        print(s)
        s = s.replace("VIV", "IX")
        print(s)
        
        s = s.replace("XXXXX", "L")
        print(s)
        s = s.replace("XXXX", "XL")
        print(s)
        
        s = s.replace("LL", "C")
        print(s)
        s = s.replace("LXL", "XC")
        print(s)
        
        s = s.replace("CCCCC", "D")
        print(s)
        s = s.replace("CCCC", "CD")
        print(s)
        
        s = s.replace("DD", "M")
        print(s)
        s = s.replace("CDC", "CM")
        print(s)


        return s
    @classmethod
    def from_roman(cls, roman: str):
        pass
print(RomanNumerals.to_roman(230495))
# Out:
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMCDXCV
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMCDXCV
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMCDXCV

# %%
import unittest

class TestCode(unittest.TestCase):

    def test_to_roman(test):
      test.assertEquals(RomanNumerals.to_roman(1000), 'M', '1000 should == "M"')
      test.assertEquals(RomanNumerals.to_roman(1990), 'MCMXC', '1990 should == "MCMXC"')
    def test_from_roman(test):
      test.assertEquals(RomanNumerals.from_roman('XXI'), 21, 'XXI should == 21')
      test.assertEquals(RomanNumerals.from_roman('MMVIII'), 2008, 'MMVIII should == 2008')

if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: Please use assertEqual instead.
#   if __name__ == '__main__':
# F/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: Please use assertEqual instead.
#
# F
# ======================================================================
# FAIL: test_from_roman (__main__.TestCode)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-21-edf83f29d03c>", line 9, in test_from_roman
#     test.assertEquals(RomanNumerals.from_roman('XXI'), 21, 'XXI should == 21')
# AssertionError: None != 21 : XXI should == 21
#
# ======================================================================
# FAIL: test_to_roman (__main__.TestCode)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-21-edf83f29d03c>", line 6, in test_to_roman
#     test.assertEquals(RomanNumerals.to_roman(1000), 'M', '1000 should == "M"')
# AssertionError: None != 'M' : 1000 should == "M"
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.007s
#
# FAILED (failures=2)
